# %% [markdown]
# # Create Spark Session

# %%
import pyspark

from pyspark.sql import SparkSession
s=SparkSession.builder.appName('ecommerce').getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/06 16:08:53 WARN Utils: Your hostname, swalih-Victus-by-HP-Gaming-Laptop-15-fb0xxx, resolves to a loopback address: 127.0.1.1; using 10.193.184.236 instead (on interface wlo1)
# 26/03/06 16:08:53 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/06 16:08:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
s
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.193.184.236:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>ecommerce</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Read csv file

# %%
# header=True → first row contains column names
# inferSchema=True → Spark automatically detects data types

df = s.read.csv(
    "ecommerce_dirty_dataset.csv",  # file name
    header=True,        # Use first row as column names
    inferSchema=True    # Automatically detect column data types
)

# %%
df.show(15)
# Out:
# +--------+-------------+---------+----------+--------+------+
# |order_id|customer_name|     city|   product|quantity| price|
# +--------+-------------+---------+----------+--------+------+
# |       1|         NULL|  Calicut|     Phone|     5.0|1569.0|
# |       2|         Neha|Bangalore|Headphones|     4.0|1616.0|
# |       3|        Rahul|    Delhi|   Monitor|     5.0|1525.0|
# |       4|        Kiran|  Chennai|  Keyboard|    NULL|1022.0|
# |       5|        Ahmed|    Delhi|    Camera|     3.0| 264.0|
# |       6|          Anu|    Kochi|    Tablet|     3.0|  NULL|
# |       7|        Aisha|    Delhi|  Keyboard|     1.0| 698.0|
# |       8|         Neha|    Kochi|      NULL|     3.0| 954.0|
# |       9|        Priya|Bangalore|Headphones|     1.0| 350.0|
# |      10|         Neha|  Chennai|    Tablet|     3.0|1980.0|
# |      11|        Kiran|Bangalore|  Keyboard|     3.0| 861.0|
# |      12|        Sneha|    Kochi|     Phone|     3.0|1235.0|
# |      13|        Priya|   Mumbai|     Phone|     3.0| 144.0|
# |      14|        Kiran|    Delhi|Headphones|     2.0| 691.0|
# |      15|        Rahul|Bangalore|  Keyboard|     5.0| 511.0|
# +--------+-------------+---------+----------+--------+------+
# only showing top 15 rows

# %% [markdown]
# ## Head

# %%
df.head(5)
# Out:
# [Row(order_id=1, customer_name=None, city='Calicut', product='Phone', quantity=5.0, price=1569.0),
#  Row(order_id=2, customer_name='Neha', city='Bangalore', product='Headphones', quantity=4.0, price=1616.0),
#  Row(order_id=3, customer_name='Rahul', city='Delhi', product='Monitor', quantity=5.0, price=1525.0),
#  Row(order_id=4, customer_name='Kiran', city='Chennai', product='Keyboard', quantity=None, price=1022.0),
#  Row(order_id=5, customer_name='Ahmed', city='Delhi', product='Camera', quantity=3.0, price=264.0)]

# %% [markdown]
# ## Info about the dataframe

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- quantity: double (nullable = true)
#  |-- price: double (nullable = true)

# %% [markdown]
# ## For all columns names

# %%
df.columns
# Out:
# ['order_id', 'customer_name', 'city', 'product', 'quantity', 'price']

# %% [markdown]
# ## Select specific columns

# %%
df.select('order_id','city').show()
# Out:
# +--------+---------+
# |order_id|     city|
# +--------+---------+
# |       1|  Calicut|
# |       2|Bangalore|
# |       3|    Delhi|
# |       4|  Chennai|
# |       5|    Delhi|
# |       6|    Kochi|
# |       7|    Delhi|
# |       8|    Kochi|
# |       9|Bangalore|
# |      10|  Chennai|
# |      11|Bangalore|
# |      12|    Kochi|
# |      13|   Mumbai|
# |      14|    Delhi|
# |      15|Bangalore|
# |      16|    Delhi|
# |      17|  Chennai|
# |      18|    Kochi|
# |      19|Bangalore|
# |      20|  Chennai|
# +--------+---------+
# only showing top 20 rows

# %% [markdown]
# ## Describe

# %%
df.describe().show()
# Out:
# 26/03/06 16:09:01 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------+------------------+-------------+---------+-------+------------------+------------------+
# |summary|          order_id|customer_name|     city|product|          quantity|             price|
# +-------+------------------+-------------+---------+-------+------------------+------------------+
# |  count|               112|          104|      105|    106|               106|               104|
# |   mean|49.607142857142854|         NULL|     NULL|   NULL|3.0283018867924527|1050.8173076923076|
# | stddev| 28.79262829294061|         NULL|     NULL|   NULL|1.2832811158441166| 571.0831603262479|
# |    min|                 1|        Ahmed|Bangalore| Camera|               1.0|             114.0|
# |    max|               100|       Vikram|   Mumbai| Tablet|               5.0|            1980.0|
# +-------+------------------+-------------+---------+-------+------------------+------------------+

# %% [markdown]
# ## Add column

# %%
df=df.withColumn('price with GST',df['price']*1.1)

# %%
df.show()
# Out:
# +--------+-------------+---------+----------+--------+------+------------------+
# |order_id|customer_name|     city|   product|quantity| price|    price with GST|
# +--------+-------------+---------+----------+--------+------+------------------+
# |       1|         NULL|  Calicut|     Phone|     5.0|1569.0|            1725.9|
# |       2|         Neha|Bangalore|Headphones|     4.0|1616.0|1777.6000000000001|
# |       3|        Rahul|    Delhi|   Monitor|     5.0|1525.0|1677.5000000000002|
# |       4|        Kiran|  Chennai|  Keyboard|    NULL|1022.0|            1124.2|
# |       5|        Ahmed|    Delhi|    Camera|     3.0| 264.0|290.40000000000003|
# |       6|          Anu|    Kochi|    Tablet|     3.0|  NULL|              NULL|
# |       7|        Aisha|    Delhi|  Keyboard|     1.0| 698.0| 767.8000000000001|
# |       8|         Neha|    Kochi|      NULL|     3.0| 954.0|            1049.4|
# |       9|        Priya|Bangalore|Headphones|     1.0| 350.0|385.00000000000006|
# |      10|         Neha|  Chennai|    Tablet|     3.0|1980.0|            2178.0|
# |      11|        Kiran|Bangalore|  Keyboard|     3.0| 861.0|             947.1|
# |      12|        Sneha|    Kochi|     Phone|     3.0|1235.0|            1358.5|
# |      13|        Priya|   Mumbai|     Phone|     3.0| 144.0|             158.4|
# |      14|        Kiran|    Delhi|Headphones|     2.0| 691.0|             760.1|
# |      15|        Rahul|Bangalore|  Keyboard|     5.0| 511.0|             562.1|
# |      16|        Priya|    Delhi|  Keyboard|     1.0|1234.0|            1357.4|
# |      17|         Neha|  Chennai|    Tablet|    NULL| 722.0|             794.2|
# |      18|        Rahul|    Kochi|    Tablet|     3.0| 812.0|             893.2|
# |      19|         Neha|Bangalore|    Laptop|     4.0|1217.0|            1338.7|
# |      20|        Rahul|  Chennai|      NULL|     3.0| 244.0|268.40000000000003|
# +--------+-------------+---------+----------+--------+------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Rename the column

# %%
df=df.withColumnRenamed('price with GST','Total price')

# %%
df.show()
# Out:
# +--------+-------------+---------+----------+--------+------+------------------+
# |order_id|customer_name|     city|   product|quantity| price|       Total price|
# +--------+-------------+---------+----------+--------+------+------------------+
# |       1|         NULL|  Calicut|     Phone|     5.0|1569.0|            1725.9|
# |       2|         Neha|Bangalore|Headphones|     4.0|1616.0|1777.6000000000001|
# |       3|        Rahul|    Delhi|   Monitor|     5.0|1525.0|1677.5000000000002|
# |       4|        Kiran|  Chennai|  Keyboard|    NULL|1022.0|            1124.2|
# |       5|        Ahmed|    Delhi|    Camera|     3.0| 264.0|290.40000000000003|
# |       6|          Anu|    Kochi|    Tablet|     3.0|  NULL|              NULL|
# |       7|        Aisha|    Delhi|  Keyboard|     1.0| 698.0| 767.8000000000001|
# |       8|         Neha|    Kochi|      NULL|     3.0| 954.0|            1049.4|
# |       9|        Priya|Bangalore|Headphones|     1.0| 350.0|385.00000000000006|
# |      10|         Neha|  Chennai|    Tablet|     3.0|1980.0|            2178.0|
# |      11|        Kiran|Bangalore|  Keyboard|     3.0| 861.0|             947.1|
# |      12|        Sneha|    Kochi|     Phone|     3.0|1235.0|            1358.5|
# |      13|        Priya|   Mumbai|     Phone|     3.0| 144.0|             158.4|
# |      14|        Kiran|    Delhi|Headphones|     2.0| 691.0|             760.1|
# |      15|        Rahul|Bangalore|  Keyboard|     5.0| 511.0|             562.1|
# |      16|        Priya|    Delhi|  Keyboard|     1.0|1234.0|            1357.4|
# |      17|         Neha|  Chennai|    Tablet|    NULL| 722.0|             794.2|
# |      18|        Rahul|    Kochi|    Tablet|     3.0| 812.0|             893.2|
# |      19|         Neha|Bangalore|    Laptop|     4.0|1217.0|            1338.7|
# |      20|        Rahul|  Chennai|      NULL|     3.0| 244.0|268.40000000000003|
# +--------+-------------+---------+----------+--------+------+------------------+
# only showing top 20 rows

# %% [markdown]
# ## Drop column

# %%
## droping the "price" column

df.drop('price').show()
# Out:
# +--------+-------------+---------+----------+--------+------------------+
# |order_id|customer_name|     city|   product|quantity|       Total price|
# +--------+-------------+---------+----------+--------+------------------+
# |       1|         NULL|  Calicut|     Phone|     5.0|            1725.9|
# |       2|         Neha|Bangalore|Headphones|     4.0|1777.6000000000001|
# |       3|        Rahul|    Delhi|   Monitor|     5.0|1677.5000000000002|
# |       4|        Kiran|  Chennai|  Keyboard|    NULL|            1124.2|
# |       5|        Ahmed|    Delhi|    Camera|     3.0|290.40000000000003|
# |       6|          Anu|    Kochi|    Tablet|     3.0|              NULL|
# |       7|        Aisha|    Delhi|  Keyboard|     1.0| 767.8000000000001|
# |       8|         Neha|    Kochi|      NULL|     3.0|            1049.4|
# |       9|        Priya|Bangalore|Headphones|     1.0|385.00000000000006|
# |      10|         Neha|  Chennai|    Tablet|     3.0|            2178.0|
# |      11|        Kiran|Bangalore|  Keyboard|     3.0|             947.1|
# |      12|        Sneha|    Kochi|     Phone|     3.0|            1358.5|
# |      13|        Priya|   Mumbai|     Phone|     3.0|             158.4|
# |      14|        Kiran|    Delhi|Headphones|     2.0|             760.1|
# |      15|        Rahul|Bangalore|  Keyboard|     5.0|             562.1|
# |      16|        Priya|    Delhi|  Keyboard|     1.0|            1357.4|
# |      17|         Neha|  Chennai|    Tablet|    NULL|             794.2|
# |      18|        Rahul|    Kochi|    Tablet|     3.0|             893.2|
# |      19|         Neha|Bangalore|    Laptop|     4.0|            1338.7|
# |      20|        Rahul|  Chennai|      NULL|     3.0|268.40000000000003|
# +--------+-------------+---------+----------+--------+------------------+
# only showing top 20 rows
